# %%
import pandas as pd
import os

import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np

import torch
import torchvision.utils as vutils
from itertools import product
import torch.nn as nn



from preprocessing.filters import apply_all_filters
from preprocessing.patch_generator import smash_n_reconstruct
import matplotlib.pyplot as plt
import numpy as np

from preprocessing.patch_generator import smash_n_reconstruct
import preprocessing.filters as f
import tensorflow as tf
from keras import layers,Model
from keras.callbacks import ModelCheckpoint, EarlyStopping
import os
# Out:
# Requirement already satisfied: keras in /opt/miniconda3/lib/python3.12/site-packages (3.8.0)
# Requirement already satisfied: absl-py in /opt/miniconda3/lib/python3.12/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/miniconda3/lib/python3.12/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/miniconda3/lib/python3.12/site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /opt/miniconda3/lib/python3.12/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/miniconda3/lib/python3.12/site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /opt/miniconda3/lib/python3.12/site-packages (from keras) (0.14.0)
# Requirement already satisfied: ml-dtypes in /opt/miniconda3/lib/python3.12/site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/miniconda3/lib/python3.12/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/lib/python3.12/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
DATA_PATH = "data/"

TRAIN_IMAGES = DATA_PATH + "train_data/"
TRAIN_IDS = DATA_PATH + "train.csv"

TEST_IMAGES = DATA_PATH + "test_data_v2/"
TEST_IDS = DATA_PATH + "test.csv"

# Show the first image in the training set

train_images_paths = os.listdir(TRAIN_IMAGES)
test_image = TRAIN_IMAGES + train_images_paths[13]

# %%
rt1,pt1 = smash_n_reconstruct(test_image)
rt2 = apply_all_filters(rt1)
pt2 = apply_all_filters(pt1)


plt.subplot(1,2,1)
plt.imshow(rt2, cmap = 'gray')
plt.title('rich texture')
plt.subplot(1,2,2)
plt.imshow(pt2, cmap = 'gray')
plt.title('poor texture')
plt.show()

plt.imshow(plt.imread(test_image))
plt.show()

# %%
train_csv = pd.read_csv(TRAIN_IDS)

ai_img_paths   = train_csv[train_csv.label==1].file_name
real_img_paths = train_csv[train_csv.label==0].file_name

check_ai   = list(ai_img_paths[:20])
check_real = list(real_img_paths[:20])

# %%
for i in range(5):
    ai_img   = "data/" + check_ai[i]
    real_img = "data/" + check_real[i]
  
    a_rt1, a_pt1 = smash_n_reconstruct(ai_img)
    r_rt1, r_pt1 = smash_n_reconstruct(real_img)

    a_rt2 = apply_all_filters(a_rt1)
    a_pt2 = apply_all_filters(a_pt1)

    r_rt2 = apply_all_filters(r_rt1)
    r_pt2 = apply_all_filters(r_pt1)

    plt.figure(figsize=(12, 6))  # You can adjust the width (12) and height (6) as needed
    plt.subplot(1, 4, 1)
    plt.imshow(a_rt2, cmap='gray')
    plt.title('Rich Texture - AI Image ')
    plt.subplot(1, 4, 2)
    plt.imshow(a_pt2, cmap='gray')
    plt.title('Poor Texture - AI Image')
    plt.subplot(1, 4, 3)
    plt.imshow(r_rt2, cmap='gray')
    plt.title('Rich Texture - Real Image')
    plt.subplot(1, 4, 4)
    plt.imshow(r_pt2, cmap='gray')
    plt.title('Poor Texture - Real Image')
    plt.show()

# %%
    
def hard_tanh(x):
    return torch.clamp(x, min=-1, max=1)

class FeatureExtractionLayer(nn.Module):
    def __init__(self):
        super(FeatureExtractionLayer, self).__init__()
        self.conv = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1)  # Assuming 3 input channels
        self.bn = nn.BatchNorm2d(32)
        self.activation = hard_tanh
        
    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.activation(x)
        return x

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class FeatureExtractionLayer(nn.Module):
    def __init__(self):
        super(FeatureExtractionLayer, self).__init__()
        self.conv = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)  # Assuming 1 input channel
        self.bn = nn.BatchNorm2d(32)
        
    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = torch.clamp(x, min=-1, max=1)
        return x

class RichPoorTextureContrast(nn.Module):
    def __init__(self):
        super(RichPoorTextureContrast, self).__init__()
        
        # Feature extraction layers
        self.feature_extraction_rich = FeatureExtractionLayer()
        self.feature_extraction_poor = FeatureExtractionLayer()
        
        # Convolutional blocks
        self.conv1 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv_blocks = nn.ModuleList([
            nn.Conv2d(32, 32, kernel_size=3, padding=1) for _ in range(6)
        ])
        self.bn_blocks = nn.ModuleList([
            nn.BatchNorm2d(32) for _ in range(6)
        ])
        
        # Average Pooling layers
        self.avgpool1 = nn.AvgPool2d(2)
        self.avgpool2 = nn.AvgPool2d(2)
        
        # Final layers
        self.global_avgpool = nn.AdaptiveAvgPool2d(1)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32, 1)
        
    def forward(self, input1, input2):
        # Feature extraction
        l1 = self.feature_extraction_rich(input1)
        l2 = self.feature_extraction_poor(input2)
        
        # Contrast layer
        contrast = l1 - l2
        
        # First Conv Block
        x = F.relu(self.conv1(contrast))
        x = self.bn1(x)
        
        # 3 Conv Blocks
        for conv, bn in zip(self.conv_blocks[:3], self.bn_blocks[:3]):
            x = F.relu(conv(x))
            x = bn(x)
        
        # Average Pooling Layer
        x = self.avgpool1(x)
        
        # 2 Conv Blocks
        for conv, bn in zip(self.conv_blocks[3:5], self.bn_blocks[3:5]):
            x = F.relu(conv(x))
            x = bn(x)
        
        # Average Pooling Layer
        x = self.avgpool2(x)
        
        # 2 Conv Blocks
        for conv, bn in zip(self.conv_blocks[5:], self.bn_blocks[5:]):
            x = F.relu(conv(x))
            x = bn(x)
        
        # Global Average Pooling
        x = self.global_avgpool(x)
        
        # Flatten and Dense layer
        x = self.flatten(x)
        x = torch.sigmoid(self.fc(x))
        
        return x

# Model instantiation
model = RichPoorTextureContrast()

# Print model summary
print(model)
# Out:
# RichPoorTextureContrast(
#   (feature_extraction_rich): FeatureExtractionLayer(
#     (conv): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (feature_extraction_poor): FeatureExtractionLayer(
#     (conv): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv_blocks): ModuleList(
#     (0-5): 6 x Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (bn_blocks): ModuleList(
#     (0-5): 6 x BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (avgpool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (avgpool2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (global_avgpool): AdaptiveAvgPool2d(output_size=1)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
def preprocess(path, label: int):
    # Assuming 'smash_n_reconstruct' and 'f.apply_all_filters' are available in your codebase
    rt, pt = smash_n_reconstruct(path)  # path is assumed to be a string, not a tensor here
    frt = torch.tensor(f.apply_all_filters(rt), dtype=torch.float32).unsqueeze(-1)
    fpt = torch.tensor(f.apply_all_filters(pt), dtype=torch.float32).unsqueeze(-1)
    return frt, fpt, label

def dict_map(X1,X2,y):
    return {
        'rich_texture':X1,
        'poor_texture':X2
    },y

# %%
ai_imgs = ["data/"+ pth for pth in ai_img_paths]
ai_label = [1 for i in range(len(ai_imgs))]

real_imgs = ["data/"+ pth for pth in real_img_paths]
real_label = [0 for i in range(len(real_imgs))]

data_ratio = int(len(ai_imgs)*0.008)

ai_imgs = ai_imgs[:data_ratio]
ai_label = ai_label[:data_ratio]
real_imgs = real_imgs[:data_ratio]
real_label = real_label[:data_ratio]


print(len(real_imgs),len(ai_imgs))
X_train = ai_imgs[:-21] + real_imgs[:-21]
y_train = ai_label[:-21] + real_label[:-21]
X_validate = ai_imgs[-21:] + real_imgs[-21:]
y_validate = ai_label[-21:] + real_label[-21:]
len(X_train),len(y_train),len(X_validate),len(y_validate)
# Out:
# 319 319
# (596, 596, 42, 42)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

class CustomDataset(Dataset):
    def __init__(self, filepaths, labels, preprocess_fn, dict_map_fn=None):
        self.filepaths = filepaths
        self.labels = labels
        self.preprocess_fn = preprocess_fn
        self.dict_map_fn = dict_map_fn
    
    def __len__(self):
        return len(self.filepaths)
    
    def __getitem__(self, idx):
        filepath = self.filepaths[idx]
        label = self.labels[idx]
        frt, fpt, label = self.preprocess_fn(filepath, label)
        
        if self.dict_map_fn:
            return self.dict_map_fn(frt, fpt, label)
        return frt, fpt, label



# Define batch size
batch_size = 32

# Create training and validation datasets
train_dataset = CustomDataset(X_train, y_train, preprocess, dict_map_fn=dict_map)
val_dataset = CustomDataset(X_validate, y_validate, preprocess, dict_map_fn=dict_map)

# Create DataLoader for batching and prefetching
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=10, shuffle=False, num_workers=0)

# The DataLoader will handle batching and shuffling, similar to TensorFlow's Dataset

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm  # Import tqdm

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize model, loss, and optimizer
model = RichPoorTextureContrast().to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training parameters
num_epochs = 10

# Training loop with tqdm
for epoch in range(num_epochs):
    # Training phase
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    
    # Wrap train loader with tqdm
    train_loop = tqdm(train_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Train]', leave=False)
    
    for batch_idx, batch in enumerate(train_loop, start=1):
        inputs, labels = batch
        rich = inputs['rich_texture'].permute(0, 3, 1, 2).float().to(device)
        poor = inputs['poor_texture'].permute(0, 3, 1, 2).float().to(device)
        labels = labels.float().to(device)
        
        # Forward pass
        outputs = model(rich, poor)
        loss = criterion(outputs, labels.unsqueeze(1))
        
        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Calculate metrics
        train_loss += loss.item()
        predicted = (outputs > 0.5).float()
        correct_train += (predicted == labels.unsqueeze(1)).sum().item()
        total_train += labels.size(0)
        
        # Update progress bar
        train_loop.set_postfix({
            'loss': f'{train_loss / batch_idx:.4f}',
            'acc': f'{correct_train / total_train:.4f}'
        })
    
    # Validation phase
    model.eval()
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    
    # Wrap validation loader with tqdm
    val_loop = tqdm(val_loader, desc=f'Epoch {epoch+1}/{num_epochs} [Val]', leave=False)
    
    with torch.no_grad():
        for batch_idx, batch in enumerate(val_loop, start=1):
            inputs, labels = batch
            rich = inputs['rich_texture'].permute(0, 3, 1, 2).float().to(device)
            poor = inputs['poor_texture'].permute(0, 3, 1, 2).float().to(device)
            labels = labels.float().to(device)
            
            outputs = model(rich, poor)
            loss = criterion(outputs, labels.unsqueeze(1))
            
            val_loss += loss.item()
            predicted = (outputs > 0.5).float()
            correct_val += (predicted == labels.unsqueeze(1)).sum().item()
            total_val += labels.size(0)
            
            # Update progress bar
            val_loop.set_postfix({
                'loss': f'{val_loss / batch_idx:.4f}',
                'acc': f'{correct_val / total_val:.4f}'
            })
    
    # Print epoch statistics
    print(f'\nEpoch [{epoch+1}/{num_epochs}]')
    print(f'Train Loss: {train_loss / len(train_loader):.4f} | Acc: {correct_train / total_train:.4f}')
    print(f'Val Loss: {val_loss / len(val_loader):.4f} | Acc: {correct_val / total_val:.4f}\n')
# Out:
# Epoch [1/10]
# Train Loss: 0.6059 | Acc: 0.6695
# Val Loss: 0.7128 | Acc: 0.5000
# Epoch [2/10]
# Train Loss: 0.5215 | Acc: 0.7701
# Val Loss: 0.5922 | Acc: 0.6667
# Epoch [3/10]
# Train Loss: 0.5120 | Acc: 0.7383
# Val Loss: 0.6883 | Acc: 0.7143
# Epoch [4/10]
# Train Loss: 0.4861 | Acc: 0.7685
# Val Loss: 0.5625 | Acc: 0.7381
# Epoch [5/10]
# Train Loss: 0.5049 | Acc: 0.7433
# Val Loss: 0.8325 | Acc: 0.7143
# Epoch [6/10]
# Train Loss: 0.4666 | Acc: 0.7685
# Val Loss: 0.4758 | Acc: 0.7857
# Epoch [7/10]
# Train Loss: 0.4559 | Acc: 0.7836
# Val Loss: 0.4771 | Acc: 0.7857
# Epoch [8/10]
# Train Loss: 0.4554 | Acc: 0.7752
# Val Loss: 0.5449 | Acc: 0.7143
# Epoch [9/10]
# Train Loss: 0.4306 | Acc: 0.7886
# Val Loss: 0.3931 | Acc: 0.8333
# Epoch [10/10]
# Train Loss: 0.4166 | Acc: 0.8205
# Val Loss: 1.5058 | Acc: 0.6429

# %%
torch.save(model.state_dict(), "model_weights.pth")

# %%
TEST_IMAGES = DATA_PATH + "test_data_v2/"
TEST_IDS = DATA_PATH + "test.csv"

# Show the first image in the training set

test_images_paths = os.listdir(TEST_IMAGES)

test_images_paths

# %%
test_ids_csv = pd.read_csv(TEST_IDS)
test_ids_csv
# Out:
#                                                      id
# 0     test_data_v2/1a2d9fd3e21b4266aea1f66b30aed157.jpg
# 1     test_data_v2/ab5df8f441fe4fbf9dc9c6baae699dc7.jpg
# 2     test_data_v2/eb364dd2dfe34feda0e52466b7ce7956.jpg
# 3     test_data_v2/f76c2580e9644d85a741a42c6f6b39c0.jpg
# 4     test_data_v2/a16495c578b7494683805484ca27cf9f.jpg
# ...                                                 ...
# 5535  test_data_v2/483412064ff74d9d9472d606b65976d9.jpg
# 5536  test_data_v2/c0b49ba4081a4197b422dac7c15aea7f.jpg
# 5537  test_data_v2/01454aaedec140c0a3ca1f48028c41cf.jpg
# 5538  test_data_v2/e9adfea8b67e4791968c4c2bdd8ec343.jpg
# 5539  test_data_v2/ba8f4198e8d74d3394fa56c56af23442.jpg
#
# [5540 rows x 1 columns]

# %%
def predict(file_path):
    rt, pt, _ = preprocess("data/" + file_path, 0)
    
    rt = rt.unsqueeze(0)
    pt = pt.unsqueeze(0)
    
    rich = rt.permute(0, 3, 1, 2).float().to(device)
    poor = pt.permute(0, 3, 1, 2).float().to(device)


    model.eval()  # Ensure the model is in evaluation mode
    with torch.no_grad():  # Disable gradient computation for inference
        output = model(rich, poor)

    label = (output >= 0.5).int().item()

    return label 

predict("train_data/"+train_images_paths[13])
# Out:
# 0

# %%
# Enable tqdm for pandas
tqdm.pandas()

# Apply the function with a progress bar
test_ids_csv["label"] = test_ids_csv["id"].progress_apply(predict)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 5540/5540 [27:10<00:00,  3.40it/s]

# %%
test_ids_csv
test_ids_csv['id'] = test_ids_csv.index

# %%
test_ids_csv[['id', 'label']].to_csv('submission.csv', index=False)

# %%
test_ids_csv.to_csv("submission.csv", index=False)

# %%
submission = pd.read_csv("submission.csv")
submission

submission['id'] = submission.index + 1

# %%
submission
# Out:
#         id  label
# 0        1      0
# 1        2      1
# 2        3      0
# 3        4      1
# 4        5      0
# ...    ...    ...
# 5535  5536      1
# 5536  5537      1
# 5537  5538      1
# 5538  5539      1
# 5539  5540      0
#
# [5540 rows x 2 columns]

# %%
submission.to_csv("submission.csv", index=False)

# %%
test = pd.read_csv(TEST_IDS)
test["label"] = submission["label"]

test.to_csv("submission.csv", index=False)
